# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn import metrics
from sklearn.metrics import confusion_matrix as sk_confusion_matrix
from sklearn.metrics import roc_auc_score, auc
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_colwidth', None)

# %%
sms_df = pd.read_table('SMSSpamCollection', header=None, names=['Class', 'sms'])
sms_df.head()
# Out:
#   Class  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                            sms
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though

# %%
len(sms_df)
# Out:
# 5572

# %%
ham_spam = sms_df.Class.value_counts()
ham_spam
# Out:
# ham     4825
# spam     747
# Name: Class, dtype: int64

# %%
print('Spam percentage: ', round(100*(ham_spam[1] / len(sms_df)), 2))
# Out:
# Spam percentage:  13.41

# %%
sms_df['label'] = sms_df.Class.map({'ham': 0, 'spam': 1})

# %%
sms_df.head()
# Out:
#   Class  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                            sms  \
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though
#
#    label
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0

# %%
X = sms_df.sms
y = sms_df.label

# %%
print( X.shape)
# Out:
# (5572,)

# %%
print( y.shape)
# Out:
# (5572,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.70, random_state=1)

# %%
X_train.head()
# Out:
# 4393                                                                                                    what are your new years plans?
# 216                                                                         Finally the match heading towards draw as your prediction.
# 4471                                 Lemme know when I can swing by and pick up, I'm free basically any time after 1 all this semester
# 3889                                                                                                ok....take care.umma to you too...
# 5030    I'd like to tell you my deepest darkest fantasies. Call me 09094646631 just 60p/min. To stop texts call 08712460324 (nat rate)
# Name: sms, dtype: object

# %%
X_test.head()
# Out:
# 1078                                                                                   Yep, by the pretty sculpture
# 4028                                                                  Yes, princess. Are you going to make me moan?
# 958                                                                                      Welp apparently he retired
# 4642                                                                                                        Havent.
# 4674    I forgot 2 ask ü all smth.. There's a card on da present lei... How? Ü all want 2 write smth or sign on it?
# Name: sms, dtype: object

# %%
y_train.head()
# Out:
# 4393    0
# 216     0
# 4471    0
# 3889    0
# 5030    1
# Name: label, dtype: int64

# %%
y_test.head()
# Out:
# 1078    0
# 4028    0
# 958     0
# 4642    0
# 4674    0
# Name: label, dtype: int64

# %%
vec = CountVectorizer(stop_words='english')

# %%
vec.fit(X_train)
# Out:
# CountVectorizer(stop_words='english')

# %%
vec.get_feature_names_out()
# Out:
# array(['00', '000', '008704050406', ..., 'zyada', 'èn', '〨ud'],
#       dtype=object)

# %%
vec.vocabulary_
# Out:
# {'new': 4272,
#  'years': 6855,
#  'plans': 4682,
#  'finally': 2550,
#  'match': 3930,
#  'heading': 3018,
#  'draw': 2202,
#  'prediction': 4801,
#  'lemme': 3650,
#  'know': 3548,
#  'swing': 5957,
#  'pick': 4644,
#  'free': 2663,
#  'basically': 1119,
#  'time': 6163,
#  'semester': 5369,
#  'ok': 4406,
#  'care': 1485,
#  'umma': 6353,
#  'like': 3685,
#  'tell': 6043,
#  'deepest': 2000,
#  'darkest': 1949,
#  'fantasies': 2478,
#  '09094646631': 222,
#  'just': 3472,
#  '60p': 538,
#  'min': 4022,
#  'stop': 5804,
#  'texts': 6083,
#  '08712460324': 103,
#  'nat': 4218,
#  'rate': 4985,
#  'lmao': 3732,
#  'fish': 2566,
#  'memory': 3984,
#  'need': 4243,
#  'yahoo': 6841,
#  'boys': 1324,
#  'bring': 1354,
#  'perf': 4592,
#  'legal': 3644,
#  'hiya': 3083,
#  'comin': 1722,
#  'bristol': 1358,
#  'st': 5740,
#  'week': 6637,
#  'april': 940,
#  'les': 3656,
#  'got': 2862,
#  'rudi': 5234,
#  'yrs': 6882,
#  'eve': 2383,
#  'snoring': 5603,
#  'drunk': 2226,
#  'bak': 1092,
#  'college': 1710,
#  'work': 6769,
#  'sends': 5374,
#  'ink': 3289,
#  'bath': 1123,
#  'wamma': 6574,
#  'laid': 3581,
#  'want': 6580,
#  'real': 5008,
#  'doggin': 2157,
#  'locations': 3740,
#  'sent': 5379,
#  'direct': 2102,
#  'mobile': 4081,
#  'join': 3435,
#  'uks': 6350,
#  'largest': 3601,
#  'dogging': 2158,
#  'network': 4265,
#  'txt': 6327,
#  'dogs': 2160,
#  '69696': 552,
#  'nyt': 4370,
#  'ec2a': 2273,
#  '3lp': 433,
#  '50': 499,
#  'msg': 4148,
#  'wat': 6598,
#  'coming': 1723,
#  'later': 3608,
#  'lor': 3773,
#  'miss': 4048,
#  'ya': 6839,
#  'love': 3794,
#  'saw': 5300,
#  'guys': 2938,
#  'dolls': 2168,
#  'night': 4290,
#  'patrick': 4559,
#  'swayze': 5946,
#  'great': 2893,
#  'yes': 6863,
#  'baby': 1078,
#  'stretch': 5824,
#  'open': 4432,
#  'pussy': 4922,
#  'going': 2834,
#  'tirunelvali': 6172,
#  'uncle': 6359,
#  'spend': 5695,
#  'taking': 5987,
#  'dress': 2208,
#  'money': 4105,
#  'feb': 2503,
#  'hey': 3062,
#  'hot': 3137,
#  'xxx': 6832,
#  'pics': 4648,
#  'ur': 6414,
#  'phone': 4629,
#  'porn': 4744,
#  '69855': 554,
#  '24hrs': 342,
#  '50p': 504,
#  'day': 1967,
#  'text': 6074,
#  'stopbcm': 5807,
#  'sf': 5402,
#  'wc1n3xx': 6615,
#  'jay': 3398,
#  'snickering': 5601,
#  'tells': 6045,
#  'totally': 6239,
#  'fucking': 2705,
#  'chords': 1631,
#  'speak': 5680,
#  'stupid': 5852,
#  'possible': 4758,
#  'different': 2085,
#  'feeling': 2509,
#  'wavering': 6610,
#  'decisions': 1992,
#  'coping': 1808,
#  'individual': 3273,
#  'heal': 3021,
#  'believe': 1172,
#  've': 6471,
#  'brainy': 1329,
#  'dear': 1979,
#  'messages': 4001,
#  'recharge': 5042,
#  'hi': 3066,
#  'come': 1717,
#  'tomorrow': 6212,
#  'wake': 6561,
#  'thanx': 6093,
#  'tau': 6011,
#  'sar': 5280,
#  'piah': 4642,
#  'quite': 4947,
#  'nice': 4283,
#  'sure': 5925,
#  'trying': 6296,
#  'hold': 3099,
#  'probably': 4849,
#  'earlier': 2256,
#  'station': 5767,
#  'think': 6116,
#  'don': 2171,
#  'lt': 3814,
#  'gt': 2915,
#  'times': 6164,
#  'oh': 4401,
#  'hypertension': 3191,
#  'true': 6286,
#  'knw': 3552,
#  'dis': 2108,
#  'doing': 2164,
#  'langport': 3592,
#  'sorry': 5649,
#  'll': 3729,
#  'bed': 1155,
#  '9pm': 687,
#  'sucks': 5881,
#  'ill': 3228,
#  'xmas': 6826,
#  'go2sri': 2825,
#  'lanka': 3594,
#  'urgent': 6417,
#  'awarded': 1058,
#  '000': 1,
#  'bonus': 1276,
#  'caller': 1450,
#  'prize': 4846,
#  '08': 41,
#  '03': 13,
#  '2nd': 381,
#  'attempt': 1020,
#  'contact': 1783,
#  '0871': 86,
#  '4719': 472,
#  '523': 513,
#  'box95qu': 1318,
#  'bt': 1380,
#  'national': 4223,
#  'da': 1929,
#  'thangam': 6086,
#  'mistake': 4057,
#  'wow': 6792,
#  'didn': 2075,
#  'common': 1729,
#  'freak': 2659,
#  'unless': 6386,
#  'chop': 1630,
#  'lots': 3783,
#  'used': 6430,
#  'ones': 4423,
#  'babe': 1076,
#  'model': 4091,
#  'doesn': 2152,
#  'help': 3045,
#  'youi': 6875,
#  'right': 5176,
#  'pls': 4698,
#  'send': 5371,
#  'message': 3999,
#  'jus': 3471,
#  'finish': 2557,
#  'blowing': 1257,
#  'hair': 2955,
#  'dinner': 2098,
#  'wet': 6669,
#  'welcome': 6650,
#  'reply': 5115,
#  'age': 799,
#  'gender': 2768,
#  'begin': 1166,
#  '24m': 343,
#  'aah': 693,
#  'cuddle': 1898,
#  'lush': 3826,
#  'tea': 6023,
#  'soup': 5663,
#  'kind': 3529,
#  'fumbling': 2709,
#  'romcapspam': 5209,
#  'responding': 5139,
#  'presence': 4816,
#  'warm': 6587,
#  'outgoing': 4479,
#  'bringing': 1355,
#  'breath': 1343,
#  'sunshine': 5908,
#  'tv': 6320,
#  'available': 1043,
#  'place': 4673,
#  'bread': 1335,
#  'milk': 4017,
#  'home': 3107,
#  'dont': 2174,
#  'play': 4683,
#  'life': 3675,
#  'eat': 2268,
#  'jap': 3393,
#  'oso': 4468,
#  'aft': 794,
#  'lect': 3641,
#  '12': 255,
#  'rite': 5189,
#  'daily': 1936,
#  'favour': 2498,
#  'lar': 3597,
#  'joking': 3442,
#  'wif': 6694,
#  'oni': 4424,
#  'fri': 2676,
#  'ah': 809,
#  'okie': 4410,
#  'goin': 2833,
#  'drivin': 2215,
#  'den': 2025,
#  'shoppin': 5457,
#  'tt': 6303,
#  'good': 2847,
#  'thing': 6114,
#  'getting': 2790,
#  'connection': 1771,
#  'bw': 1427,
#  'din': 2094,
#  'chachi': 1546,
#  'tried': 6278,
#  'calling': 1455,
#  'unable': 6356,
#  'reach': 4999,
#  'pl': 4672,
#  'missed': 4050,
#  'cal': 1438,
#  'tiz': 6179,
#  'kanagu': 3486,
#  'responsibilities': 5141,
#  'morning': 4124,
#  'amp': 867,
#  'successful': 5877,
#  'current': 1910,
#  'food': 2615,
#  'shoot': 5455,
#  'big': 1206,
#  'loads': 3735,
#  'ready': 5007,
#  'ho': 3095,
#  'belly': 1176,
#  'laugh': 3612,
#  'tomo': 6210,
#  'dun': 2242,
#  'ain': 817,
#  'answerin': 893,
#  'actually': 749,
#  'pretty': 4827,
#  'reasonable': 5022,
#  'hour': 3141,
#  'sleepy': 5552,
#  'omg': 4419,
#  'did': 2074,
#  'ate': 1012,
#  'long': 3759,
#  'does': 2150,
#  'applebees': 927,
#  'sending': 5373,
#  'greetings': 2897,
#  'joy': 3450,
#  'happiness': 2988,
#  'gr8': 2874,
#  'evening': 2385,
#  'friendship': 2684,
#  'game': 2734,
#  'word': 6767,
#  'say': 5301,
#  'start': 5761,
#  'march': 3908,
#  'ends': 2325,
#  'yesterday': 6865,
#  'today': 6196,
#  'dunno': 2244,
#  'lei': 3648,
#  'thk': 6124,
#  'mum': 4169,
#  'lazy': 3623,
#  'neva': 4268,
#  'ask': 991,
#  'awww': 1063,
#  'dat': 1957,
#  'sweet': 5949,
#  'tonight': 6217,
#  'cos': 1817,
#  'im': 3231,
#  'lonely': 3758,
#  'important': 3246,
#  'information': 3282,
#  'orange': 4452,
#  'user': 6433,
#  '0796xxxxxx': 38,
#  'lucky': 3820,
#  'log': 3745,
#  'http': 3159,
#  'www': 6817,
#  'urawinner': 6415,
#  'com': 1714,
#  'fantastic': 2479,
#  'prizeawaiting': 4847,
#  'pic': 4643,
#  '8th': 671,
#  'campus': 1463,
#  'atm': 1017,
#  'secret': 5344,
#  'admirer': 763,
#  'looking': 3766,
#  'make': 3881,
#  'reveal': 5161,
#  'thinks': 6120,
#  'special': 5682,
#  '09065171142': 200,
#  'stopsms': 5811,
#  'medical': 3962,
#  '7pm': 590,
#  'forward': 2644,
#  'height': 3038,
#  'confidence': 1761,
#  'aeronautics': 782,
#  'professors': 4859,
#  'wer': 6659,
#  'calld': 1448,
#  'askd': 992,
#  'sit': 5523,
#  'aeroplane': 783,
#  'aftr': 797,
#  'sat': 5287,
#  'told': 6203,
#  'plane': 4678,
#  'ws': 6807,
#  'students': 5842,
#  'dey': 2061,
#  'hurried': 3179,
#  'didnt': 2076,
#  'said': 5262,
#  'wont': 6759,
#  'datz': 1964,
#  'half': 2959,
#  'longer': 3760,
#  'syria': 5966,
#  'canada': 1464,
#  'eh': 2297,
#  'extra': 2440,
#  'grins': 2899,
#  'desperate': 2047,
#  'armand': 965,
#  'wrong': 6804,
#  'number': 4355,
#  'cud': 1897,
#  'bout': 1300,
#  '30pm': 404,
#  'pub': 4901,
#  'attending': 1022,
#  'talks': 5994,
#  'waaaat': 6548,
#  'lololo': 3754,
#  'guess': 2925,
#  'created': 1862,
#  'web': 6625,
#  'page': 4503,
#  'asjesus': 990,
#  'read': 5004,
#  'wrote': 6806,
#  'waiting': 6560,
#  'opinions': 4440,
#  'friend': 2681,
#  'lunch': 3824,
#  'gettin': 2789,
#  'rdy': 4998,
#  'ship': 5440,
#  'comp': 1731,
#  'nvm': 4364,
#  'wear': 6620,
#  'sport': 5722,
#  'shoes': 5453,
#  'late': 3606,
#  'leh': 3647,
#  'wylie': 6818,
#  'tampa': 5999,
#  'sarasota': 5281,
#  'bought': 1298,
#  'test': 6069,
#  'lets': 3661,
#  'exact': 2403,
#  'ovulate': 4491,
#  '2u': 388,
#  '3wks': 442,
#  'fret': 2675,
#  'worried': 6778,
#  'relax': 5080,
#  'past': 4552,
#  'history': 3078,
#  'mu': 4162,
#  'seconds': 5343,
#  'bored': 1288,
#  'speed': 5689,
#  'dating': 1962,
#  'try': 6294,
#  'speedchat': 5690,
#  '80155': 600,
#  'em': 2310,
#  'swap': 5941,
#  'chatter': 1576,
#  'chat80155': 1575,
#  'pobox36504w45wq': 4712,
#  '150p': 281,
#  'rcd': 4993,
#  '16': 290,
#  'merry': 3996,
#  'christmas': 1636,
#  'kisses': 3538,
#  'double': 2187,
#  'mins': 4035,
#  'txts': 6334,
#  '6months': 564,
#  'bluetooth': 1261,
#  'sony': 5637,
#  'nokia': 4313,
#  'motorola': 4132,
#  'phones': 4633,
#  'mobileupd8': 4085,
#  '08000839402': 45,
#  'call2optout': 1445,
#  'n9dx': 4195,
#  'directly': 2103,
#  'abt': 711,
#  'rows': 5223,
#  'waqt': 6586,
#  'se': 5334,
#  'pehle': 4582,
#  'naseeb': 4216,
#  'zyada': 6901,
#  'kisi': 3536,
#  'ko': 3553,
#  'kuch': 3562,
#  'nahi': 4202,
#  'milta': 4021,
#  'zindgi': 6898,
#  'wo': 6747,
#  'jo': 3428,
#  'hum': 3170,
#  'sochte': 5608,
#  'hai': 2953,
#  'ham': 2965,
#  'jeetey': 3407,
#  'board': 1266,
#  'working': 6772,
#  'fine': 2554,
#  'issue': 3361,
#  'overheating': 4488,
#  'reslove': 5133,
#  'software': 5612,
#  'inst': 3304,
#  'pending': 4586,
#  'clock': 1665,
#  'specialisation': 5683,
#  'slave': 5545,
#  'labor': 3573,
#  'look': 3763,
#  'month': 4114,
#  'sha': 5405,
#  'shakara': 5410,
#  'beggar': 1164,
#  'problem': 4850,
#  'yup': 6890,
#  'sch': 5310,
#  'rem': 5086,
#  'correctly': 1815,
#  'grinder': 2898,
#  'nope': 4324,
#  'market': 3913,
#  'cocksuckers': 1693,
#  'makes': 3882,
#  'feel': 2507,
#  'better': 1192,
#  'ipads': 3341,
#  'worthless': 6785,
#  'garbage': 2741,
#  'novelty': 4345,
#  'items': 3366,
#  'bad': 1085,
#  'wanting': 6583,
#  'running': 5243,
#  'managed': 3893,
#  'minutes': 4038,
#  'needed': 4245,
#  'oxygen': 4496,
#  'resort': 5135,
#  'roller': 5207,
#  'option': 4448,
#  'floppy': 2595,
#  'snappy': 5597,
#  'happy': 2989,
#  'gay': 2753,
#  'chat': 1574,
#  'service': 5389,
#  'photo': 4635,
#  'upload': 6408,
#  '08718730666': 134,
#  '10p': 243,
#  'questions': 4942,
#  '08712402578': 96,
#  'immediately': 3240,
#  'check': 1583,
#  'detailed': 2050,
#  'rooms': 5215,
#  'cheap': 1578,
#  'thanks': 6088,
#  'visa': 6512,
#  'buying': 1422,
#  'gucci': 2920,
#  'bags': 1090,
#  'sister': 5521,
#  'things': 6115,
#  'easy': 2267,
#  'john': 3434,
#  'bills': 1212,
#  'really': 5016,
#  'difficulties': 2087,
#  'works': 6774,
#  'request': 5120,
#  'search': 5336,
#  'main': 3877,
#  'sources': 5665,
#  'unhappiness': 6373,
#  'accept': 718,
#  'way': 6612,
#  'comes': 1719,
#  'moment': 4100,
#  'live': 3722,
#  'words': 6768,
#  'silence': 5501,
#  'gud': 2921,
#  'mrng': 4145,
#  'include': 3256,
#  'details': 2051,
#  'slept': 5553,
#  'hope': 3121,
#  'enjoy': 2334,
#  'driving': 2216,
#  'lesson': 3658,
#  'boytoy': 1325,
#  'teasing': 6032,
#  'kiss': 3537,
#  'yo': 6870,
#  'gonna': 2845,
#  'stock': 5796,
#  'dubsack': 2233,
#  'happen': 2980,
#  'behave': 1170,
#  'man': 3890,
#  'fighting': 2533,
#  'world': 6775,
#  'win': 6704,
#  'lose': 3775,
#  'fightng': 2534,
#  'some1': 5620,
#  'close': 1668,
#  'dificult': 2088,
#  'hmm': 3088,
#  'news': 4277,
#  'hype': 3190,
#  'park': 4535,
#  'plaza': 4690,
#  '700': 570,
#  'studio': 5844,
#  'taken': 5984,
#  'left': 3643,
#  'bedrm': 1157,
#  '900': 673,
#  'gym': 2941,
#  'sell': 5365,
#  'fast': 2486,
#  'office': 4393,
#  'mesages': 3997,
#  'thats': 6096,
#  'hurts': 3183,
#  'performance': 4595,
#  'award': 1057,
#  'calculated': 1439,
#  'period': 4598,
#  'guy': 2937,
#  'bitching': 1226,
#  'acted': 740,
#  'interested': 3314,
#  'gave': 2752,
#  'looked': 3764,
#  'addie': 756,
#  'goes': 2831,
#  'monday': 4104,
#  'figure': 2536,
#  'mind': 4025,
#  'bedroom': 1158,
#  'minute': 4037,
#  'sed': 5352,
#  'sexy': 5399,
#  'mood': 4118,
#  'came': 1461,
#  'minuts': 4039,
#  'latr': 3611,
#  'wid': 6692,
#  'cake': 1437,
#  'wife': 6695,
#  'funk': 2715,
#  'fone': 2611,
#  'weekly': 6641,
#  'tone': 6213,
#  'tones2u': 6215,
#  'ringtones': 5184,
#  'uk': 6348,
#  'original': 4463,
#  'best': 1187,
#  'tones': 6214,
#  '3gbp': 430,
#  'operator': 4438,
#  'rates': 4986,
#  'apply': 930,
#  'afternoon': 796,
#  'job': 3430,
#  'prospects': 4887,
#  'missing': 4052,
#  'bleak': 1241,
#  'hmmm': 3089,
#  'filled': 2540,
#  'robinson': 5196,
#  'remember': 5089,
#  'valued': 6457,
#  'customer': 1916,
#  'pleased': 4691,
#  'advise': 779,
#  'following': 2609,
#  'recent': 5038,
#  'review': 5164,
#  'mob': 4079,
#  '1500': 280,
#  '09066364589': 211,
#  'hook': 3119,
#  'went': 6657,
#  'party': 4542,
#  'boyfriend': 1323,
#  'si': 5489,
#  'shadow': 5406,
#  'early': 2258,
#  'spring': 5730,
#  'yay': 6851,
#  'attracts': 1027,
#  'brothas': 1367,
#  'dependents': 2035,
#  'shall': 5414,
#  'mail': 3874,
#  'tonite': 6219,
#  'busy': 1415,
#  'street': 5821,
#  'update': 6403,
#  'varunnathu': 6464,
#  'edukkukayee': 2285,
#  'raksha': 4972,
#  'ollu': 4415,
#  'sense': 5376,
#  'aight': 816,
#  'informed': 3283,
#  'hello': 3043,
#  'handsome': 2973,
#  'finding': 2553,
#  'net': 4260,
#  'mummy': 4172,
#  'ugh': 6345,
#  'gotta': 2866,
#  'drive': 2214,
#  'sd': 5332,
#  'la': 3568,
#  'butt': 1416,
#  'sore': 5646,
#  'write': 6798,
#  'pookie': 4735,
#  'pie': 4652,
#  'lol': 3752,
#  'meeting': 3968,
#  'ammae': 864,
#  'takes': 5985,
#  'lot': 3781,
#  'turns': 6318,
#  'steering': 5781,
#  'wishing': 6726,
#  'moji': 4095,
#  'offer': 4389,
#  'speechless': 5688,
#  'easily': 2263,
#  'lengths': 3652,
#  'behalf': 1169,
#  'stunning': 5851,
#  'exam': 2405,
#  'friday': 2677,
#  'touch': 6241,
#  'let': 3660,
#  'noe': 4307,
#  'leave': 3638,
#  'house': 3144,
#  'alright': 851,
#  'befor': 1162,
#  'activities': 747,
#  'sir': 5518,
#  'letter': 3662,
#  'theory': 6105,
#  'argument': 959,
#  'wins': 6716,
#  'situation': 5527,
#  'loses': 3777,
#  'person': 4606,
#  'argue': 957,
#  'friends': 2682,
#  'kick': 3516,
#  'correct': 1813,
#  'theres': 6108,
#  'class': 1651,
#  'tmrw': 6187,
#  'won': 6752,
#  'cash': 1506,
#  'claim': 1646,
#  'call09050000327': 1444,
#  'rstm': 5228,
#  'sw7': 5937,
#  '3ss': 440,
#  '150ppm': 285,
#  'host': 3134,
#  'based': 1117,
#  'idps': 3219,
#  'linux': 3705,
#  'systems': 5968,
#  'truro': 6290,
#  'hospital': 3132,
#  'ext': 2439,
#  'rush': 5246,
#  'received': 5036,
#  'understood': 6368,
#  'activate': 745,
#  '500': 500,
#  'replying': 5116,
#  'terms': 6060,
#  'conditions': 1757,
#  'visit': 6514,
#  '07781482378': 28,
#  'thankyou': 6092,
#  'appreciate': 934,
#  'luck': 3818,
#  '28th': 355,
#  '06': 19,
#  'removal': 5098,
#  '87239': 647,
#  'services': 5390,
#  '08708034412': 83,
#  'mean': 3952,
#  'watching': 6602,
#  'na': 4196,
#  'ideas': 3213,
#  'invention': 3327,
#  'fly': 2601,
#  'cleared': 1658,
#  'round': 5218,
#  'birla': 1218,
#  'soft': 5611,
#  'alrite': 852,
#  'idiot': 3217,
#  'girlie': 2805,
#  'father': 2490,
#  '____': 691,
#  'ans': 889,
#  'ths': 6143,
#  'hav': 3006,
#  'iq': 3344,
#  'tis': 6174,
#  'ias': 3194,
#  'question': 4940,
#  'answer': 891,
#  'okay': 4407,
#  'ring': 5180,
#  'weekend': 6639,
#  'wot': 6786,
#  'juan': 3458,
#  'course': 1834,
#  'expect': 2424,
#  'presents': 4818,
#  'nicky': 4286,
#  'loosu': 3772,
#  'careless': 1491,
#  'use': 6429,
#  'having': 3011,
#  'hoping': 3125,
#  'meets': 3970,
#  'abiola': 701,
#  'smile': 5579,
#  'pleasure': 4693,
#  'pain': 4507,
#  'trouble': 6283,
#  'pours': 4773,
#  'rain': 4963,
#  'sum1': 5898,
#  'becoz': 1153,
#  'loves': 3801,
#  'smiling': 5582,
#  'sleep': 5546,
#  'nite': 4300,
#  'whos': 6686,
#  'general': 2769,
#  'price': 4831,
#  'oz': 4498,
#  'cause': 1521,
#  'nauseous': 4229,
#  'pissed': 4666,
#  'sweets': 5953,
#  'planning': 4681,
#  'pig': 4656,
#  'dieting': 2081,
#  'hungry': 3174,
#  '08707509020': 81,
#  '20p': 331,
#  'ntt': 4351,
#  'po': 4706,
#  'box': 1304,
#  '1327': 268,
#  'croydon': 1879,
#  'cr9': 1846,
#  '5wb': 529,
#  '0870': 66,
#  'scream': 5326,
#  'weighed': 6643,
#  'lost': 3780,
#  'weight': 6644,
#  'woohoo': 6763,
#  'ou': 4472,
#  'guaranteed': 2919,
#  'latest': 3609,
#  '40gb': 451,
#  'ipod': 3343,
#  'mp3': 4141,
#  'player': 4685,
#  'collect': 1706,
#  '83355': 621,
#  'ibhltd': 3196,
#  'ldnw15h': 3627,
#  'mtmsgrcvd18': 4160,
#  'intro': 3324,
#  'pilates': 4657,
#  'kickboxing': 3517,
#  'ringtone': 5182,
#  'changed': 1556,
#  '25': 344,
#  'credits': 1866,
#  'club4mobiles': 1678,
#  'choose': 1628,
#  'content': 1786,
#  'club': 1676,
#  '87070': 642,
#  'wk': 6734,
#  'club4': 1677,
#  'box1146': 1305,
#  'mk45': 4067,
#  '2wt': 392,
#  'dialogue': 2068,
#  'cute': 1920,
#  'reltnship': 5085,
#  'wen': 6654,
#  'die': 2078,
#  'near': 4237,
#  'body': 1270,
#  'bcoz': 1140,
#  'hands': 2971,
#  'wipe': 6718,
#  'tears': 6030,
#  'ni8': 4281,
#  'post': 4759,
#  '1000s': 236,
#  'reading': 5006,
#  'wiv': 6732,
#  'caroline': 1499,
#  'end': 2321,
#  'favourite': 2499,
#  'bless': 1242,
#  'boy': 1320,
#  'ass': 999,
#  'quick': 4943,
#  'idea': 3211,
#  'anyplaces': 904,
#  'mapquest': 3904,
#  'usf': 6435,
#  'dogwood': 2161,
#  'tiny': 6167,
#  'parking': 4538,
#  'cartoon': 1504,
#  'listening': 3715,
#  'music': 4183,
#  'temple': 6052,
#  'church': 1638,
#  'birthday': 1222,
#  'download': 2192,
#  'clear': 1657,
#  'movies': 4138,
#  'dvd': 2249,
#  'copies': 1807,
#  'felt': 2515,
#  'conveying': 1798,
#  'reason': 5021,
#  'ese': 2370,
#  '86888': 639,
#  'reward': 5166,
#  'hours': 3143,
#  'talk': 5989,
#  'subscribe6gbp': 5866,
#  'mnth': 4075,
#  '3hrs': 431,
#  'txtstop': 6335,
#  'gamb': 2733,
#  'nutter': 4362,
#  'cutter': 1923,
#  'ctter': 1894,
#  'cttergg': 1895,
#  'cttargg': 1893,
#  'ctargg': 1891,
#  'ctagg': 1890,
#  'poop': 4737,
#  'looks': 3767,
#  'prob': 4848,
#  'laptop': 3596,
#  'fixed': 2571,
#  'cuz': 1925,
#  'gpu': 2873,
#  'cutest': 1922,
#  'girl': 2803,
#  'agree': 808,
#  'thinkin': 6118,
#  'ipad': 3339,
#  'macho': 3857,
#  'hear': 3023,
#  'year': 6854,
#  'moves': 4136,
#  ...}

# %%
len(vec.vocabulary_.keys())
# Out:
# 6904

# %%
X_train_transformed = vec.transform(X_train)
X_test_transformed = vec.transform(X_test)

# %%
print(type(X_train_transformed))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
print(X_test_transformed)
# Out:
#   (0, 4827)	1
#   (0, 6861)	1
#   (1, 2834)	1
#   (1, 3881)	1
#   (1, 4078)	1
#   (1, 4837)	1
#   (1, 6863)	1
#   (2, 922)	1
#   (2, 6653)	1
#   (3, 3009)	1
#   (4, 991)	1
#   (4, 1481)	1
#   (4, 1929)	1
#   (4, 2635)	1
#   (4, 3648)	1
#   (4, 4817)	1
#   (4, 5497)	1
#   (4, 5594)	2
#   (4, 6580)	1
#   (4, 6798)	1
#   (5, 1717)	1
#   (5, 2862)	1
#   (5, 4406)	1
#   (5, 6124)	1
#   (5, 6575)	1
#   :	:
#   (1664, 6580)	1
#   (1665, 4827)	1
#   (1665, 4922)	1
#   (1665, 6580)	1
#   (1666, 3107)	1
#   (1666, 6612)	1
#   (1667, 42)	1
#   (1667, 1864)	1
#   (1667, 2663)	1
#   (1667, 3045)	1
#   (1667, 3736)	1
#   (1667, 5065)	1
#   (1667, 6074)	1
#   (1668, 794)	1
#   (1668, 1717)	2
#   (1668, 3240)	1
#   (1668, 3658)	1
#   (1668, 4644)	1
#   (1668, 6414)	1
#   (1669, 4354)	1
#   (1670, 4407)	1
#   (1670, 6088)	1
#   (1671, 3608)	1
#   (1671, 3729)	1
#   (1671, 5649)	1

# %% [markdown]
# ###  Model training

# %%
bnb = BernoulliNB()

bnb.fit(X_train_transformed, y_train)

pred_y_class = bnb.predict(X_test_transformed)

pred_y_prob = bnb.predict_proba(X_test_transformed)

# %%
bnb.get_params()
# Out:
# {'alpha': 1.0,
#  'binarize': 0.0,
#  'class_prior': None,
#  'fit_prior': True,
#  'force_alpha': 'warn'}

# %%
metrics.accuracy_score(y_test, pred_y_class)
# Out:
# 0.9730861244019139

# %%
metrics.confusion_matrix(y_test, pred_y_class)
# Out:
# array([[1441,    1],
#        [  44,  186]])

# %%
confusion = metrics.confusion_matrix(y_test, pred_y_class)
print(confusion)
TP = confusion[1,1]
TN = confusion[0,0]
FP = confusion[0,1]
FN = confusion[1,0]
# Out:
# [[1441    1]
#  [  44  186]]

# %%
sensitivity = TP / float(TP + FN)
print(sensitivity)
# Out:
# 0.808695652173913

# %%
specificity = TN / float(TN + FP)
print(specificity)
# Out:
# 0.9993065187239945

# %%
precision = TP / float(TP + FP)
print(precision)
# Out:
# 0.9946524064171123

# %%
recall = TP / float(TP + FN)
print(recall)
# Out:
# 0.808695652173913

# %%
print('Precision score: ', metrics.precision_score(y_test, pred_y_class))
print('recall score: ', metrics.recall_score(y_test, pred_y_class))
print('f1 scode: ', metrics.f1_score(y_test, pred_y_class))
# Out:
# Precision score:  0.9946524064171123
# recall score:  0.808695652173913
# f1 scode:  0.8920863309352518

# %%
print(pred_y_prob[:,1])
# Out:
# [9.96618134e-11 1.06705743e-10 2.00329203e-09 ... 4.59975661e-10
#  1.84159288e-10 6.67666387e-13]

# %%
false_positive_rate, true_positive_rate ,threshold = metrics.roc_curve(y_test, pred_y_prob[:,1])

# %%
roc_auc = auc(false_positive_rate, true_positive_rate)
print(roc_auc)
# Out:
# 0.9963155038292226

# %%
pd.DataFrame({'TRP': true_positive_rate,
             'FPR': false_positive_rate,
             'threshold': threshold})
# Out:
#           TRP       FPR     threshold
# 0    0.000000  0.000000           inf
# 1    0.234783  0.000000  1.000000e+00
# 2    0.256522  0.000000  1.000000e+00
# 3    0.282609  0.000000  1.000000e+00
# 4    0.295652  0.000000  1.000000e+00
# ..        ...       ...           ...
# 138  1.000000  0.923717  3.696064e-13
# 139  1.000000  0.925104  3.678742e-13
# 140  1.000000  0.933426  2.950141e-13
# 141  1.000000  0.934813  2.897876e-13
# 142  1.000000  1.000000  7.247475e-17
#
# [143 rows x 3 columns]

# %%
plt.xlabel('False Positive Rate ')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.plot(false_positive_rate,true_positive_rate)

# %% [markdown]
# ## In this specific case, we are more interested in high specificity

# %% [markdown]
# ### Specificity implies that out of all the genuine SMS's, how many of them were correctly predicted as legitimate by the model.
